# %%
import numpy as np
import time

def read_data(filename):
    input_f=open(filename, 'r')
    input_data=[]
    for line in input_f.readlines():
        input_data.append([float(val) for val in line.split(',')])
    input_data=np.array(input_data)
    train_x=input_data[:,:-2]
    train_y=input_data[:,-2:-1]
    train_x=np.concatenate((train_x, np.ones((train_x.shape[0],1))),axis=1)
    n, dimension = train_x.shape
    return n, dimension, train_x, train_y
    
n, dimension, train_x, train_y = read_data('classification.txt')
train_x, np.squeeze(train_y)
# Out:
# (array([[0.750072  , 0.97740794, 0.88565752, 1.        ],
#         [0.87791369, 0.01925101, 0.50671112, 1.        ],
#         [0.7773246 , 0.99406596, 0.82224385, 1.        ],
#         ...,
#         [0.5155064 , 0.15354364, 0.01275495, 1.        ],
#         [0.2282263 , 0.97155357, 0.18305906, 1.        ],
#         [0.36391513, 0.49207061, 0.71952659, 1.        ]]),
#  array([-1.,  1., -1., ...,  1., -1., -1.]))

# %%
pos_zero_threshold = 1e-7
neg_zero_threshold = -1e-7

def activate(val, threshold = neg_zero_threshold):
    activation_func = np.vectorize(lambda x: 1.0 if x > threshold else -1.0)
    return activation_func(val)

def predict(n, train_x, train_y, W):
    return activate(np.dot(train_x, W.reshape(-1,1)))

def pocket(n, dimension, train_x, train_y, max_epoch, learning_rate):
    weight = np.array([-1.0]*dimension)
    misclassification = []

    best_match = 0
    best_weight = None
    
    for epoch in range(max_epoch):
        hypothesis=predict(n, train_x, train_y, weight)*train_y
        
        delta = hypothesis*learning_rate*train_x
     
        match = (np.abs(predict(n, train_x, train_y, weight)-train_y)<pos_zero_threshold).sum()
        
        accuracy = 1.0*match/n
    
        if match > best_match:
            best_match = match
            best_weight = weight[:]
    
        if match==n:
            break

        weight-=np.squeeze(np.dot(delta.T,train_y).T)
        
        misclassification.append(n - match)
        
        print 'Epoch #%d, accuracy_rate=%.3f' % (epoch, accuracy)

    return best_weight, 1.0*best_match/n, predict(n, train_x, train_y, best_weight), epoch, misclassification

start_time = time.time()
weight, accuracy, prediction, epoch, misclassification = pocket(n, dimension, train_x, train_y, max_epoch=7000, learning_rate=1e-6)
print 'After %d epoch(s), %.3f s elapsed:'% (epoch, time.time()-start_time)
print 'Weight matrix =', weight
print 'Accuracy rate=%.2f' % accuracy
# Out:
# Epoch #0, accuracy_rate=0.677
# Epoch #1, accuracy_rate=0.677
# Epoch #2, accuracy_rate=0.677
# Epoch #3, accuracy_rate=0.677
# Epoch #4, accuracy_rate=0.677
# Epoch #5, accuracy_rate=0.677
# Epoch #6, accuracy_rate=0.677
# Epoch #7, accuracy_rate=0.677
# Epoch #8, accuracy_rate=0.677
# Epoch #9, accuracy_rate=0.677
# Epoch #10, accuracy_rate=0.677
# Epoch #11, accuracy_rate=0.677
# Epoch #12, accuracy_rate=0.677
# Epoch #13, accuracy_rate=0.677
# Epoch #14, accuracy_rate=0.677
# Epoch #15, accuracy_rate=0.677
# Epoch #16, accuracy_rate=0.677
# Epoch #17, accuracy_rate=0.677
# Epoch #18, accuracy_rate=0.677
# Epoch #19, accuracy_rate=0.677
# Epoch #20, accuracy_rate=0.677
# Epoch #21, accuracy_rate=0.677
# Epoch #22, accuracy_rate=0.677
# Epoch #23, accuracy_rate=0.677
# Epoch #24, accuracy_rate=0.677
# Epoch #25, accuracy_rate=0.677
# Epoch #26, accuracy_rate=0.677
# Epoch #27, accuracy_rate=0.677
# Epoch #28, accuracy_rate=0.677
# Epoch #29, accuracy_rate=0.677
# Epoch #30, accuracy_rate=0.677
# Epoch #31, accuracy_rate=0.677
# Epoch #32, accuracy_rate=0.677
# Epoch #33, accuracy_rate=0.677
# Epoch #34, accuracy_rate=0.677
# Epoch #35, accuracy_rate=0.677
# Epoch #36, accuracy_rate=0.677
# Epoch #37, accuracy_rate=0.677
# Epoch #38, accuracy_rate=0.677
# Epoch #39, accuracy_rate=0.677
# Epoch #40, accuracy_rate=0.677
# Epoch #41, accuracy_rate=0.677
# Epoch #42, accuracy_rate=0.677
# Epoch #43, accuracy_rate=0.677
# Epoch #44, accuracy_rate=0.677
# Epoch #45, accuracy_rate=0.677
# Epoch #46, accuracy_rate=0.677
# Epoch #47, accuracy_rate=0.677
# Epoch #48, accuracy_rate=0.677
# Epoch #49, accuracy_rate=0.677
# Epoch #50, accuracy_rate=0.677
# Epoch #51, accuracy_rate=0.677
# Epoch #52, accuracy_rate=0.677
# Epoch #53, accuracy_rate=0.677
# Epoch #54, accuracy_rate=0.677
# Epoch #55, accuracy_rate=0.677
# Epoch #56, accuracy_rate=0.677
# Epoch #57, accuracy_rate=0.677
# Epoch #58, accuracy_rate=0.677
# Epoch #59, accuracy_rate=0.677
# Epoch #60, accuracy_rate=0.677
# Epoch #61, accuracy_rate=0.677
# Epoch #62, accuracy_rate=0.677
# Epoch #63, accuracy_rate=0.677
# Epoch #64, accuracy_rate=0.677
# Epoch #65, accuracy_rate=0.677
# Epoch #66, accuracy_rate=0.677
# Epoch #67, accuracy_rate=0.677
# Epoch #68, accuracy_rate=0.677
# Epoch #69, accuracy_rate=0.677
# Epoch #70, accuracy_rate=0.677
# Epoch #71, accuracy_rate=0.677
# Epoch #72, accuracy_rate=0.677
# Epoch #73, accuracy_rate=0.677
# Epoch #74, accuracy_rate=0.677
# Epoch #75, accuracy_rate=0.677
# Epoch #76, accuracy_rate=0.677
# Epoch #77, accuracy_rate=0.677
# Epoch #78, accuracy_rate=0.677
# Epoch #79, accuracy_rate=0.677
# Epoch #80, accuracy_rate=0.677
# Epoch #81, accuracy_rate=0.677
# Epoch #82, accuracy_rate=0.677
# Epoch #83, accuracy_rate=0.677
# Epoch #84, accuracy_rate=0.677
# Epoch #85, accuracy_rate=0.677
# Epoch #86, accuracy_rate=0.677
# Epoch #87, accuracy_rate=0.677
# Epoch #88, accuracy_rate=0.677
# Epoch #89, accuracy_rate=0.677
# Epoch #90, accuracy_rate=0.677
# Epoch #91, accuracy_rate=0.677
# Epoch #92, accuracy_rate=0.677
# Epoch #93, accuracy_rate=0.677
# Epoch #94, accuracy_rate=0.677
# Epoch #95, accuracy_rate=0.677
# Epoch #96, accuracy_rate=0.677
# Epoch #97, accuracy_rate=0.677
# Epoch #98, accuracy_rate=0.677
# Epoch #99, accuracy_rate=0.677
# Epoch #100, accuracy_rate=0.677
# Epoch #101, accuracy_rate=0.677
# Epoch #102, accuracy_rate=0.677
# Epoch #103, accuracy_rate=0.677
# Epoch #104, accuracy_rate=0.677
# Epoch #105, accuracy_rate=0.677
# Epoch #106, accuracy_rate=0.677
# Epoch #107, accuracy_rate=0.677
# Epoch #108, accuracy_rate=0.677
# Epoch #109, accuracy_rate=0.677
# Epoch #110, accuracy_rate=0.677
# Epoch #111, accuracy_rate=0.677
# Epoch #112, accuracy_rate=0.677
# Epoch #113, accuracy_rate=0.677
# Epoch #114, accuracy_rate=0.677
# Epoch #115, accuracy_rate=0.677
# Epoch #116, accuracy_rate=0.677
# Epoch #117, accuracy_rate=0.677
# Epoch #118, accuracy_rate=0.677
# Epoch #119, accuracy_rate=0.677
# Epoch #120, accuracy_rate=0.677
# Epoch #121, accuracy_rate=0.677
# Epoch #122, accuracy_rate=0.677
# Epoch #123, accuracy_rate=0.677
# Epoch #124, accuracy_rate=0.677
# Epoch #125, accuracy_rate=0.677
# Epoch #126, accuracy_rate=0.677
# Epoch #127, accuracy_rate=0.677
# Epoch #128, accuracy_rate=0.677
# Epoch #129, accuracy_rate=0.677
# Epoch #130, accuracy_rate=0.677
# Epoch #131, accuracy_rate=0.677
# Epoch #132, accuracy_rate=0.677
# Epoch #133, accuracy_rate=0.677
# Epoch #134, accuracy_rate=0.677
# Epoch #135, accuracy_rate=0.677
# Epoch #136, accuracy_rate=0.677
# Epoch #137, accuracy_rate=0.677
# Epoch #138, accuracy_rate=0.677
# Epoch #139, accuracy_rate=0.677
# Epoch #140, accuracy_rate=0.677
# Epoch #141, accuracy_rate=0.677
# Epoch #142, accuracy_rate=0.677
# Epoch #143, accuracy_rate=0.677
# Epoch #144, accuracy_rate=0.677
# Epoch #145, accuracy_rate=0.677
# Epoch #146, accuracy_rate=0.677
# Epoch #147, accuracy_rate=0.677
# Epoch #148, accuracy_rate=0.677
# Epoch #149, accuracy_rate=0.677
# Epoch #150, accuracy_rate=0.677
# Epoch #151, accuracy_rate=0.677
# Epoch #152, accuracy_rate=0.677
# Epoch #153, accuracy_rate=0.677
# Epoch #154, accuracy_rate=0.677
# Epoch #155, accuracy_rate=0.677
# Epoch #156, accuracy_rate=0.677
# Epoch #157, accuracy_rate=0.677
# Epoch #158, accuracy_rate=0.677
# Epoch #159, accuracy_rate=0.677
# Epoch #160, accuracy_rate=0.677
# Epoch #161, accuracy_rate=0.677
# Epoch #162, accuracy_rate=0.677
# Epoch #163, accuracy_rate=0.677
# Epoch #164, accuracy_rate=0.677
# Epoch #165, accuracy_rate=0.677
# Epoch #166, accuracy_rate=0.677
# Epoch #167, accuracy_rate=0.677
# Epoch #168, accuracy_rate=0.677
# Epoch #169, accuracy_rate=0.677
# Epoch #170, accuracy_rate=0.677
# Epoch #171, accuracy_rate=0.677
# Epoch #172, accuracy_rate=0.677
# Epoch #173, accuracy_rate=0.677
# Epoch #174, accuracy_rate=0.677
# Epoch #175, accuracy_rate=0.677
# Epoch #176, accuracy_rate=0.677
# Epoch #177, accuracy_rate=0.677
# Epoch #178, accuracy_rate=0.677
# Epoch #179, accuracy_rate=0.677
# Epoch #180, accuracy_rate=0.677
# Epoch #181, accuracy_rate=0.677
# Epoch #182, accuracy_rate=0.677
# Epoch #183, accuracy_rate=0.677
# Epoch #184, accuracy_rate=0.677
# Epoch #185, accuracy_rate=0.677
# Epoch #186, accuracy_rate=0.677
# Epoch #187, accuracy_rate=0.677
# Epoch #188, accuracy_rate=0.677
# Epoch #189, accuracy_rate=0.677
# Epoch #190, accuracy_rate=0.677
# Epoch #191, accuracy_rate=0.677
# Epoch #192, accuracy_rate=0.677
# Epoch #193, accuracy_rate=0.677
# Epoch #194, accuracy_rate=0.677
# Epoch #195, accuracy_rate=0.677
# Epoch #196, accuracy_rate=0.677
# Epoch #197, accuracy_rate=0.677
# Epoch #198, accuracy_rate=0.677
# Epoch #199, accuracy_rate=0.677
# Epoch #200, accuracy_rate=0.677
# Epoch #201, accuracy_rate=0.677
# Epoch #202, accuracy_rate=0.677
# Epoch #203, accuracy_rate=0.677
# Epoch #204, accuracy_rate=0.677
# Epoch #205, accuracy_rate=0.677
# Epoch #206, accuracy_rate=0.677
# Epoch #207, accuracy_rate=0.677
# Epoch #208, accuracy_rate=0.677
# Epoch #209, accuracy_rate=0.677
# Epoch #210, accuracy_rate=0.677
# Epoch #211, accuracy_rate=0.677
# Epoch #212, accuracy_rate=0.677
# Epoch #213, accuracy_rate=0.677
# Epoch #214, accuracy_rate=0.677
# Epoch #215, accuracy_rate=0.677
# Epoch #216, accuracy_rate=0.677
# Epoch #217, accuracy_rate=0.677
# Epoch #218, accuracy_rate=0.677
# Epoch #219, accuracy_rate=0.677
# Epoch #220, accuracy_rate=0.677
# Epoch #221, accuracy_rate=0.677
# Epoch #222, accuracy_rate=0.677
# Epoch #223, accuracy_rate=0.677
# Epoch #224, accuracy_rate=0.677
# Epoch #225, accuracy_rate=0.677
# Epoch #226, accuracy_rate=0.677
# Epoch #227, accuracy_rate=0.677
# Epoch #228, accuracy_rate=0.677
# Epoch #229, accuracy_rate=0.677
# Epoch #230, accuracy_rate=0.677
# Epoch #231, accuracy_rate=0.677
# Epoch #232, accuracy_rate=0.677
# Epoch #233, accuracy_rate=0.677
# Epoch #234, accuracy_rate=0.677
# Epoch #235, accuracy_rate=0.677
# Epoch #236, accuracy_rate=0.677
# Epoch #237, accuracy_rate=0.677
# Epoch #238, accuracy_rate=0.677
# Epoch #239, accuracy_rate=0.677
# Epoch #240, accuracy_rate=0.677
# Epoch #241, accuracy_rate=0.677
# Epoch #242, accuracy_rate=0.677
# Epoch #243, accuracy_rate=0.677
# Epoch #244, accuracy_rate=0.677
# Epoch #245, accuracy_rate=0.677
# Epoch #246, accuracy_rate=0.677
# Epoch #247, accuracy_rate=0.677
# Epoch #248, accuracy_rate=0.677
# Epoch #249, accuracy_rate=0.677
# Epoch #250, accuracy_rate=0.677
# Epoch #251, accuracy_rate=0.677
# Epoch #252, accuracy_rate=0.677
# Epoch #253, accuracy_rate=0.677
# Epoch #254, accuracy_rate=0.677
# Epoch #255, accuracy_rate=0.677
# Epoch #256, accuracy_rate=0.677
# Epoch #257, accuracy_rate=0.677
# Epoch #258, accuracy_rate=0.677
# Epoch #259, accuracy_rate=0.677
# Epoch #260, accuracy_rate=0.677
# Epoch #261, accuracy_rate=0.677
# Epoch #262, accuracy_rate=0.677
# Epoch #263, accuracy_rate=0.677
# Epoch #264, accuracy_rate=0.677
# Epoch #265, accuracy_rate=0.677
# Epoch #266, accuracy_rate=0.677
# Epoch #267, accuracy_rate=0.677
# Epoch #268, accuracy_rate=0.677
# Epoch #269, accuracy_rate=0.677
# Epoch #270, accuracy_rate=0.677
# Epoch #271, accuracy_rate=0.677
# Epoch #272, accuracy_rate=0.677
# Epoch #273, accuracy_rate=0.677
# Epoch #274, accuracy_rate=0.677
# Epoch #275, accuracy_rate=0.677
# Epoch #276, accuracy_rate=0.677
# Epoch #277, accuracy_rate=0.677
# Epoch #278, accuracy_rate=0.677
# Epoch #279, accuracy_rate=0.677
# Epoch #280, accuracy_rate=0.677
# Epoch #281, accuracy_rate=0.677
# Epoch #282, accuracy_rate=0.677
# Epoch #283, accuracy_rate=0.677
# Epoch #284, accuracy_rate=0.677
# Epoch #285, accuracy_rate=0.677
# Epoch #286, accuracy_rate=0.677
# Epoch #287, accuracy_rate=0.677
# Epoch #288, accuracy_rate=0.677
# Epoch #289, accuracy_rate=0.677
# Epoch #290, accuracy_rate=0.677
# Epoch #291, accuracy_rate=0.677
# Epoch #292, accuracy_rate=0.677
# Epoch #293, accuracy_rate=0.677
# Epoch #294, accuracy_rate=0.677
# Epoch #295, accuracy_rate=0.677
# Epoch #296, accuracy_rate=0.677
# Epoch #297, accuracy_rate=0.677
# Epoch #298, accuracy_rate=0.677
# Epoch #299, accuracy_rate=0.677
# Epoch #300, accuracy_rate=0.677
# Epoch #301, accuracy_rate=0.677
# Epoch #302, accuracy_rate=0.677
# Epoch #303, accuracy_rate=0.677
# Epoch #304, accuracy_rate=0.677
# Epoch #305, accuracy_rate=0.677
# Epoch #306, accuracy_rate=0.677
# Epoch #307, accuracy_rate=0.677
# Epoch #308, accuracy_rate=0.677
# Epoch #309, accuracy_rate=0.677
# Epoch #310, accuracy_rate=0.677
# Epoch #311, accuracy_rate=0.677
# Epoch #312, accuracy_rate=0.677
# Epoch #313, accuracy_rate=0.677
# Epoch #314, accuracy_rate=0.677
# Epoch #315, accuracy_rate=0.677
# Epoch #316, accuracy_rate=0.677
# Epoch #317, accuracy_rate=0.677
# Epoch #318, accuracy_rate=0.677
# Epoch #319, accuracy_rate=0.677
# Epoch #320, accuracy_rate=0.677
# Epoch #321, accuracy_rate=0.677
# Epoch #322, accuracy_rate=0.677
# Epoch #323, accuracy_rate=0.677
# Epoch #324, accuracy_rate=0.677
# Epoch #325, accuracy_rate=0.677
# Epoch #326, accuracy_rate=0.677
# Epoch #327, accuracy_rate=0.677
# Epoch #328, accuracy_rate=0.677
# Epoch #329, accuracy_rate=0.677
# Epoch #330, accuracy_rate=0.677
# Epoch #331, accuracy_rate=0.677
# Epoch #332, accuracy_rate=0.677
# Epoch #333, accuracy_rate=0.677
# Epoch #334, accuracy_rate=0.677
# Epoch #335, accuracy_rate=0.677
# Epoch #336, accuracy_rate=0.677
# Epoch #337, accuracy_rate=0.677
# Epoch #338, accuracy_rate=0.677
# Epoch #339, accuracy_rate=0.677
# Epoch #340, accuracy_rate=0.677
# Epoch #341, accuracy_rate=0.677
# Epoch #342, accuracy_rate=0.677
# Epoch #343, accuracy_rate=0.677
# Epoch #344, accuracy_rate=0.677
# Epoch #345, accuracy_rate=0.677
# Epoch #346, accuracy_rate=0.677
# Epoch #347, accuracy_rate=0.677
# Epoch #348, accuracy_rate=0.677
# Epoch #349, accuracy_rate=0.677
# Epoch #350, accuracy_rate=0.677
# Epoch #351, accuracy_rate=0.677
# Epoch #352, accuracy_rate=0.677
# Epoch #353, accuracy_rate=0.677
# Epoch #354, accuracy_rate=0.677
# Epoch #355, accuracy_rate=0.677
# Epoch #356, accuracy_rate=0.677
# Epoch #357, accuracy_rate=0.677
# Epoch #358, accuracy_rate=0.677
# Epoch #359, accuracy_rate=0.677
# Epoch #360, accuracy_rate=0.677
# Epoch #361, accuracy_rate=0.677
# Epoch #362, accuracy_rate=0.677
# Epoch #363, accuracy_rate=0.677
# Epoch #364, accuracy_rate=0.677
# Epoch #365, accuracy_rate=0.677
# Epoch #366, accuracy_rate=0.677
# Epoch #367, accuracy_rate=0.677
# Epoch #368, accuracy_rate=0.677
# Epoch #369, accuracy_rate=0.677
# Epoch #370, accuracy_rate=0.677
# Epoch #371, accuracy_rate=0.677
# Epoch #372, accuracy_rate=0.677
# Epoch #373, accuracy_rate=0.677
# Epoch #374, accuracy_rate=0.677
# Epoch #375, accuracy_rate=0.677
# Epoch #376, accuracy_rate=0.677
# Epoch #377, accuracy_rate=0.677
# Epoch #378, accuracy_rate=0.677
# Epoch #379, accuracy_rate=0.677
# Epoch #380, accuracy_rate=0.677
# Epoch #381, accuracy_rate=0.677
# Epoch #382, accuracy_rate=0.677
# Epoch #383, accuracy_rate=0.677
# Epoch #384, accuracy_rate=0.677
# Epoch #385, accuracy_rate=0.677
# Epoch #386, accuracy_rate=0.677
# Epoch #387, accuracy_rate=0.677
# Epoch #388, accuracy_rate=0.677
# Epoch #389, accuracy_rate=0.677
# Epoch #390, accuracy_rate=0.677
# Epoch #391, accuracy_rate=0.677
# Epoch #392, accuracy_rate=0.677
# Epoch #393, accuracy_rate=0.677
# Epoch #394, accuracy_rate=0.677
# Epoch #395, accuracy_rate=0.677
# Epoch #396, accuracy_rate=0.677
# Epoch #397, accuracy_rate=0.677
# Epoch #398, accuracy_rate=0.677
# Epoch #399, accuracy_rate=0.677
# Epoch #400, accuracy_rate=0.677
# Epoch #401, accuracy_rate=0.677
# Epoch #402, accuracy_rate=0.677
# Epoch #403, accuracy_rate=0.677
# Epoch #404, accuracy_rate=0.677
# Epoch #405, accuracy_rate=0.677
# Epoch #406, accuracy_rate=0.677
# Epoch #407, accuracy_rate=0.677
# Epoch #408, accuracy_rate=0.677
# Epoch #409, accuracy_rate=0.677
# Epoch #410, accuracy_rate=0.677
# Epoch #411, accuracy_rate=0.677
# Epoch #412, accuracy_rate=0.677
# Epoch #413, accuracy_rate=0.677
# Epoch #414, accuracy_rate=0.677
# Epoch #415, accuracy_rate=0.677
# Epoch #416, accuracy_rate=0.677
# Epoch #417, accuracy_rate=0.677
# Epoch #418, accuracy_rate=0.677
# Epoch #419, accuracy_rate=0.677
# Epoch #420, accuracy_rate=0.677
# Epoch #421, accuracy_rate=0.677
# Epoch #422, accuracy_rate=0.677
# Epoch #423, accuracy_rate=0.677
# Epoch #424, accuracy_rate=0.677
# Epoch #425, accuracy_rate=0.677
# Epoch #426, accuracy_rate=0.677
# Epoch #427, accuracy_rate=0.677
# Epoch #428, accuracy_rate=0.677
# Epoch #429, accuracy_rate=0.677
# Epoch #430, accuracy_rate=0.677
# Epoch #431, accuracy_rate=0.677
# Epoch #432, accuracy_rate=0.677
# Epoch #433, accuracy_rate=0.677
# Epoch #434, accuracy_rate=0.677
# Epoch #435, accuracy_rate=0.677
# Epoch #436, accuracy_rate=0.677
# Epoch #437, accuracy_rate=0.677
# Epoch #438, accuracy_rate=0.677
# Epoch #439, accuracy_rate=0.677
# Epoch #440, accuracy_rate=0.677
# Epoch #441, accuracy_rate=0.677
# Epoch #442, accuracy_rate=0.677
# Epoch #443, accuracy_rate=0.677
# Epoch #444, accuracy_rate=0.677
# Epoch #445, accuracy_rate=0.677
# Epoch #446, accuracy_rate=0.677
# Epoch #447, accuracy_rate=0.677
# Epoch #448, accuracy_rate=0.677
# Epoch #449, accuracy_rate=0.677
# Epoch #450, accuracy_rate=0.677
# Epoch #451, accuracy_rate=0.677
# Epoch #452, accuracy_rate=0.677
# Epoch #453, accuracy_rate=0.677
# Epoch #454, accuracy_rate=0.677
# Epoch #455, accuracy_rate=0.677
# Epoch #456, accuracy_rate=0.677
# Epoch #457, accuracy_rate=0.677
# Epoch #458, accuracy_rate=0.677
# Epoch #459, accuracy_rate=0.677
# Epoch #460, accuracy_rate=0.677
# Epoch #461, accuracy_rate=0.677
# Epoch #462, accuracy_rate=0.677
# Epoch #463, accuracy_rate=0.677
# Epoch #464, accuracy_rate=0.677
# Epoch #465, accuracy_rate=0.677
# Epoch #466, accuracy_rate=0.677
# Epoch #467, accuracy_rate=0.677
# Epoch #468, accuracy_rate=0.677
# Epoch #469, accuracy_rate=0.677
# Epoch #470, accuracy_rate=0.677
# Epoch #471, accuracy_rate=0.677
# Epoch #472, accuracy_rate=0.677
# Epoch #473, accuracy_rate=0.677
# Epoch #474, accuracy_rate=0.677
# Epoch #475, accuracy_rate=0.677
# Epoch #476, accuracy_rate=0.677
# Epoch #477, accuracy_rate=0.677
# Epoch #478, accuracy_rate=0.677
# Epoch #479, accuracy_rate=0.677
# Epoch #480, accuracy_rate=0.677
# Epoch #481, accuracy_rate=0.677
# Epoch #482, accuracy_rate=0.677
# Epoch #483, accuracy_rate=0.677
# Epoch #484, accuracy_rate=0.677
# Epoch #485, accuracy_rate=0.677
# Epoch #486, accuracy_rate=0.677
# Epoch #487, accuracy_rate=0.677
# Epoch #488, accuracy_rate=0.677
# Epoch #489, accuracy_rate=0.677
# Epoch #490, accuracy_rate=0.677
# Epoch #491, accuracy_rate=0.677
# Epoch #492, accuracy_rate=0.677
# Epoch #493, accuracy_rate=0.677
# Epoch #494, accuracy_rate=0.677
# Epoch #495, accuracy_rate=0.677
# Epoch #496, accuracy_rate=0.677
# Epoch #497, accuracy_rate=0.677
# Epoch #498, accuracy_rate=0.677
# Epoch #499, accuracy_rate=0.677
# Epoch #500, accuracy_rate=0.677
# Epoch #501, accuracy_rate=0.677
# Epoch #502, accuracy_rate=0.677
# Epoch #503, accuracy_rate=0.677
# Epoch #504, accuracy_rate=0.677
# Epoch #505, accuracy_rate=0.677
# Epoch #506, accuracy_rate=0.677
# Epoch #507, accuracy_rate=0.677
# Epoch #508, accuracy_rate=0.677
# Epoch #509, accuracy_rate=0.677
# Epoch #510, accuracy_rate=0.677
# Epoch #511, accuracy_rate=0.677
# Epoch #512, accuracy_rate=0.677
# Epoch #513, accuracy_rate=0.677
# Epoch #514, accuracy_rate=0.677
# Epoch #515, accuracy_rate=0.677
# Epoch #516, accuracy_rate=0.677
# Epoch #517, accuracy_rate=0.677
# Epoch #518, accuracy_rate=0.677
# Epoch #519, accuracy_rate=0.677
# Epoch #520, accuracy_rate=0.677
# Epoch #521, accuracy_rate=0.677
# Epoch #522, accuracy_rate=0.677
# Epoch #523, accuracy_rate=0.677
# Epoch #524, accuracy_rate=0.677
# Epoch #525, accuracy_rate=0.677
# Epoch #526, accuracy_rate=0.677
# Epoch #527, accuracy_rate=0.677
# Epoch #528, accuracy_rate=0.677
# Epoch #529, accuracy_rate=0.677
# Epoch #530, accuracy_rate=0.677
# Epoch #531, accuracy_rate=0.677
# Epoch #532, accuracy_rate=0.677
# Epoch #533, accuracy_rate=0.677
# Epoch #534, accuracy_rate=0.677
# Epoch #535, accuracy_rate=0.677
# Epoch #536, accuracy_rate=0.676
# Epoch #537, accuracy_rate=0.676
# Epoch #538, accuracy_rate=0.676
# Epoch #539, accuracy_rate=0.676
# Epoch #540, accuracy_rate=0.676
# Epoch #541, accuracy_rate=0.676
# Epoch #542, accuracy_rate=0.676
# Epoch #543, accuracy_rate=0.676
# Epoch #544, accuracy_rate=0.676
# Epoch #545, accuracy_rate=0.675
# Epoch #546, accuracy_rate=0.675
# Epoch #547, accuracy_rate=0.675
# Epoch #548, accuracy_rate=0.676
# Epoch #549, accuracy_rate=0.675
# Epoch #550, accuracy_rate=0.675
# Epoch #551, accuracy_rate=0.675
# Epoch #552, accuracy_rate=0.676
# Epoch #553, accuracy_rate=0.676
# Epoch #554, accuracy_rate=0.676
# Epoch #555, accuracy_rate=0.676
# Epoch #556, accuracy_rate=0.675
# Epoch #557, accuracy_rate=0.675
# Epoch #558, accuracy_rate=0.675
# Epoch #559, accuracy_rate=0.675
# Epoch #560, accuracy_rate=0.675
# Epoch #561, accuracy_rate=0.675
# Epoch #562, accuracy_rate=0.676
# Epoch #563, accuracy_rate=0.676
# Epoch #564, accuracy_rate=0.676
# Epoch #565, accuracy_rate=0.676
# Epoch #566, accuracy_rate=0.676
# Epoch #567, accuracy_rate=0.676
# Epoch #568, accuracy_rate=0.676
# Epoch #569, accuracy_rate=0.676
# Epoch #570, accuracy_rate=0.676
# Epoch #571, accuracy_rate=0.676
# Epoch #572, accuracy_rate=0.676
# Epoch #573, accuracy_rate=0.676
# Epoch #574, accuracy_rate=0.676
# Epoch #575, accuracy_rate=0.676
# Epoch #576, accuracy_rate=0.676
# Epoch #577, accuracy_rate=0.676
# Epoch #578, accuracy_rate=0.676
# Epoch #579, accuracy_rate=0.676
# Epoch #580, accuracy_rate=0.676
# Epoch #581, accuracy_rate=0.676
# Epoch #582, accuracy_rate=0.676
# Epoch #583, accuracy_rate=0.676
# Epoch #584, accuracy_rate=0.676
# Epoch #585, accuracy_rate=0.676
# Epoch #586, accuracy_rate=0.676
# Epoch #587, accuracy_rate=0.675
# Epoch #588, accuracy_rate=0.675
# Epoch #589, accuracy_rate=0.675
# Epoch #590, accuracy_rate=0.675
# Epoch #591, accuracy_rate=0.675
# Epoch #592, accuracy_rate=0.675
# Epoch #593, accuracy_rate=0.675
# Epoch #594, accuracy_rate=0.675
# Epoch #595, accuracy_rate=0.674
# Epoch #596, accuracy_rate=0.674
# Epoch #597, accuracy_rate=0.674
# Epoch #598, accuracy_rate=0.675
# Epoch #599, accuracy_rate=0.675
# Epoch #600, accuracy_rate=0.675
# Epoch #601, accuracy_rate=0.676
# Epoch #602, accuracy_rate=0.676
# Epoch #603, accuracy_rate=0.676
# Epoch #604, accuracy_rate=0.676
# Epoch #605, accuracy_rate=0.676
# Epoch #606, accuracy_rate=0.675
# Epoch #607, accuracy_rate=0.675
# Epoch #608, accuracy_rate=0.675
# Epoch #609, accuracy_rate=0.674
# Epoch #610, accuracy_rate=0.674
# Epoch #611, accuracy_rate=0.674
# Epoch #612, accuracy_rate=0.675
# Epoch #613, accuracy_rate=0.674
# Epoch #614, accuracy_rate=0.675
# Epoch #615, accuracy_rate=0.674
# Epoch #616, accuracy_rate=0.674
# Epoch #617, accuracy_rate=0.674
# Epoch #618, accuracy_rate=0.675
# Epoch #619, accuracy_rate=0.675
# Epoch #620, accuracy_rate=0.674
# Epoch #621, accuracy_rate=0.672
# Epoch #622, accuracy_rate=0.672
# Epoch #623, accuracy_rate=0.672
# Epoch #624, accuracy_rate=0.672
# Epoch #625, accuracy_rate=0.670
# Epoch #626, accuracy_rate=0.669
# Epoch #627, accuracy_rate=0.668
# Epoch #628, accuracy_rate=0.667
# Epoch #629, accuracy_rate=0.668
# Epoch #630, accuracy_rate=0.668
# Epoch #631, accuracy_rate=0.667
# Epoch #632, accuracy_rate=0.666
# Epoch #633, accuracy_rate=0.666
# Epoch #634, accuracy_rate=0.667
# Epoch #635, accuracy_rate=0.667
# Epoch #636, accuracy_rate=0.668
# Epoch #637, accuracy_rate=0.667
# Epoch #638, accuracy_rate=0.666
# Epoch #639, accuracy_rate=0.665
# Epoch #640, accuracy_rate=0.665
# Epoch #641, accuracy_rate=0.664
# Epoch #642, accuracy_rate=0.663
# Epoch #643, accuracy_rate=0.663
# Epoch #644, accuracy_rate=0.660
# Epoch #645, accuracy_rate=0.658
# Epoch #646, accuracy_rate=0.656
# Epoch #647, accuracy_rate=0.655
# Epoch #648, accuracy_rate=0.654
# Epoch #649, accuracy_rate=0.655
# Epoch #650, accuracy_rate=0.654
# Epoch #651, accuracy_rate=0.651
# Epoch #652, accuracy_rate=0.648
# Epoch #653, accuracy_rate=0.647
# Epoch #654, accuracy_rate=0.645
# Epoch #655, accuracy_rate=0.644
# Epoch #656, accuracy_rate=0.643
# Epoch #657, accuracy_rate=0.641
# Epoch #658, accuracy_rate=0.641
# Epoch #659, accuracy_rate=0.642
# Epoch #660, accuracy_rate=0.641
# Epoch #661, accuracy_rate=0.640
# Epoch #662, accuracy_rate=0.639
# Epoch #663, accuracy_rate=0.638
# Epoch #664, accuracy_rate=0.638
# Epoch #665, accuracy_rate=0.638
# Epoch #666, accuracy_rate=0.638
# Epoch #667, accuracy_rate=0.637
# Epoch #668, accuracy_rate=0.635
# Epoch #669, accuracy_rate=0.634
# Epoch #670, accuracy_rate=0.635
# Epoch #671, accuracy_rate=0.635
# Epoch #672, accuracy_rate=0.635
# Epoch #673, accuracy_rate=0.636
# Epoch #674, accuracy_rate=0.634
# Epoch #675, accuracy_rate=0.631
# Epoch #676, accuracy_rate=0.632
# Epoch #677, accuracy_rate=0.630
# Epoch #678, accuracy_rate=0.630
# Epoch #679, accuracy_rate=0.629
# Epoch #680, accuracy_rate=0.628
# Epoch #681, accuracy_rate=0.625
# Epoch #682, accuracy_rate=0.624
# Epoch #683, accuracy_rate=0.620
# Epoch #684, accuracy_rate=0.618
# Epoch #685, accuracy_rate=0.616
# Epoch #686, accuracy_rate=0.616
# Epoch #687, accuracy_rate=0.614
# Epoch #688, accuracy_rate=0.614
# Epoch #689, accuracy_rate=0.614
# Epoch #690, accuracy_rate=0.614
# Epoch #691, accuracy_rate=0.614
# Epoch #692, accuracy_rate=0.611
# Epoch #693, accuracy_rate=0.609
# Epoch #694, accuracy_rate=0.608
# Epoch #695, accuracy_rate=0.610
# Epoch #696, accuracy_rate=0.608
# Epoch #697, accuracy_rate=0.605
# Epoch #698, accuracy_rate=0.603
# Epoch #699, accuracy_rate=0.601
# Epoch #700, accuracy_rate=0.598
# Epoch #701, accuracy_rate=0.597
# Epoch #702, accuracy_rate=0.596
# Epoch #703, accuracy_rate=0.596
# Epoch #704, accuracy_rate=0.595
# Epoch #705, accuracy_rate=0.592
# Epoch #706, accuracy_rate=0.593
# Epoch #707, accuracy_rate=0.591
# Epoch #708, accuracy_rate=0.593
# Epoch #709, accuracy_rate=0.590
# Epoch #710, accuracy_rate=0.589
# Epoch #711, accuracy_rate=0.588
# Epoch #712, accuracy_rate=0.588
# Epoch #713, accuracy_rate=0.587
# Epoch #714, accuracy_rate=0.586
# Epoch #715, accuracy_rate=0.585
# Epoch #716, accuracy_rate=0.585
# Epoch #717, accuracy_rate=0.583
# Epoch #718, accuracy_rate=0.582
# Epoch #719, accuracy_rate=0.580
# Epoch #720, accuracy_rate=0.578
# Epoch #721, accuracy_rate=0.580
# Epoch #722, accuracy_rate=0.579
# Epoch #723, accuracy_rate=0.579
# Epoch #724, accuracy_rate=0.578
# Epoch #725, accuracy_rate=0.575
# Epoch #726, accuracy_rate=0.572
# Epoch #727, accuracy_rate=0.571
# Epoch #728, accuracy_rate=0.570
# Epoch #729, accuracy_rate=0.568
# Epoch #730, accuracy_rate=0.568
# Epoch #731, accuracy_rate=0.563
# Epoch #732, accuracy_rate=0.559
# Epoch #733, accuracy_rate=0.558
# Epoch #734, accuracy_rate=0.555
# Epoch #735, accuracy_rate=0.553
# Epoch #736, accuracy_rate=0.553
# Epoch #737, accuracy_rate=0.551
# Epoch #738, accuracy_rate=0.548
# Epoch #739, accuracy_rate=0.546
# Epoch #740, accuracy_rate=0.545
# Epoch #741, accuracy_rate=0.545
# Epoch #742, accuracy_rate=0.545
# Epoch #743, accuracy_rate=0.545
# Epoch #744, accuracy_rate=0.545
# Epoch #745, accuracy_rate=0.544
# Epoch #746, accuracy_rate=0.543
# Epoch #747, accuracy_rate=0.543
# Epoch #748, accuracy_rate=0.542
# Epoch #749, accuracy_rate=0.539
# Epoch #750, accuracy_rate=0.538
# Epoch #751, accuracy_rate=0.535
# Epoch #752, accuracy_rate=0.534
# Epoch #753, accuracy_rate=0.534
# Epoch #754, accuracy_rate=0.533
# Epoch #755, accuracy_rate=0.532
# Epoch #756, accuracy_rate=0.531
# Epoch #757, accuracy_rate=0.532
# Epoch #758, accuracy_rate=0.531
# Epoch #759, accuracy_rate=0.530
# Epoch #760, accuracy_rate=0.530
# Epoch #761, accuracy_rate=0.531
# Epoch #762, accuracy_rate=0.531
# Epoch #763, accuracy_rate=0.530
# Epoch #764, accuracy_rate=0.531
# Epoch #765, accuracy_rate=0.529
# Epoch #766, accuracy_rate=0.529
# Epoch #767, accuracy_rate=0.529
# Epoch #768, accuracy_rate=0.528
# Epoch #769, accuracy_rate=0.527
# Epoch #770, accuracy_rate=0.527
# Epoch #771, accuracy_rate=0.526
# Epoch #772, accuracy_rate=0.525
# Epoch #773, accuracy_rate=0.525
# Epoch #774, accuracy_rate=0.526
# Epoch #775, accuracy_rate=0.525
# Epoch #776, accuracy_rate=0.524
# Epoch #777, accuracy_rate=0.524
# Epoch #778, accuracy_rate=0.523
# Epoch #779, accuracy_rate=0.521
# Epoch #780, accuracy_rate=0.520
# Epoch #781, accuracy_rate=0.519
# Epoch #782, accuracy_rate=0.517
# Epoch #783, accuracy_rate=0.517
# Epoch #784, accuracy_rate=0.516
# Epoch #785, accuracy_rate=0.515
# Epoch #786, accuracy_rate=0.515
# Epoch #787, accuracy_rate=0.515
# Epoch #788, accuracy_rate=0.515
# Epoch #789, accuracy_rate=0.515
# Epoch #790, accuracy_rate=0.514
# Epoch #791, accuracy_rate=0.515
# Epoch #792, accuracy_rate=0.515
# Epoch #793, accuracy_rate=0.515
# Epoch #794, accuracy_rate=0.514
# Epoch #795, accuracy_rate=0.513
# Epoch #796, accuracy_rate=0.514
# Epoch #797, accuracy_rate=0.513
# Epoch #798, accuracy_rate=0.513
# Epoch #799, accuracy_rate=0.512
# Epoch #800, accuracy_rate=0.512
# Epoch #801, accuracy_rate=0.512
# Epoch #802, accuracy_rate=0.512
# Epoch #803, accuracy_rate=0.511
# Epoch #804, accuracy_rate=0.510
# Epoch #805, accuracy_rate=0.509
# Epoch #806, accuracy_rate=0.508
# Epoch #807, accuracy_rate=0.507
# Epoch #808, accuracy_rate=0.507
# Epoch #809, accuracy_rate=0.506
# Epoch #810, accuracy_rate=0.505
# Epoch #811, accuracy_rate=0.505
# Epoch #812, accuracy_rate=0.504
# Epoch #813, accuracy_rate=0.504
# Epoch #814, accuracy_rate=0.504
# Epoch #815, accuracy_rate=0.505
# Epoch #816, accuracy_rate=0.505
# Epoch #817, accuracy_rate=0.505
# Epoch #818, accuracy_rate=0.504
# Epoch #819, accuracy_rate=0.504
# Epoch #820, accuracy_rate=0.503
# Epoch #821, accuracy_rate=0.502
# Epoch #822, accuracy_rate=0.502
# Epoch #823, accuracy_rate=0.502
# Epoch #824, accuracy_rate=0.502
# Epoch #825, accuracy_rate=0.501
# Epoch #826, accuracy_rate=0.501
# Epoch #827, accuracy_rate=0.501
# Epoch #828, accuracy_rate=0.501
# Epoch #829, accuracy_rate=0.501
# Epoch #830, accuracy_rate=0.501
# Epoch #831, accuracy_rate=0.500
# Epoch #832, accuracy_rate=0.499
# Epoch #833, accuracy_rate=0.498
# Epoch #834, accuracy_rate=0.498
# Epoch #835, accuracy_rate=0.498
# Epoch #836, accuracy_rate=0.498
# Epoch #837, accuracy_rate=0.498
# Epoch #838, accuracy_rate=0.498
# Epoch #839, accuracy_rate=0.499
# Epoch #840, accuracy_rate=0.499
# Epoch #841, accuracy_rate=0.499
# Epoch #842, accuracy_rate=0.499
# Epoch #843, accuracy_rate=0.498
# Epoch #844, accuracy_rate=0.499
# Epoch #845, accuracy_rate=0.499
# Epoch #846, accuracy_rate=0.499
# Epoch #847, accuracy_rate=0.498
# Epoch #848, accuracy_rate=0.498
# Epoch #849, accuracy_rate=0.498
# Epoch #850, accuracy_rate=0.498
# Epoch #851, accuracy_rate=0.498
# Epoch #852, accuracy_rate=0.498
# Epoch #853, accuracy_rate=0.497
# Epoch #854, accuracy_rate=0.498
# Epoch #855, accuracy_rate=0.498
# Epoch #856, accuracy_rate=0.497
# Epoch #857, accuracy_rate=0.497
# Epoch #858, accuracy_rate=0.497
# Epoch #859, accuracy_rate=0.497
# Epoch #860, accuracy_rate=0.497
# Epoch #861, accuracy_rate=0.497
# Epoch #862, accuracy_rate=0.497
# Epoch #863, accuracy_rate=0.498
# Epoch #864, accuracy_rate=0.498
# Epoch #865, accuracy_rate=0.498
# Epoch #866, accuracy_rate=0.498
# Epoch #867, accuracy_rate=0.498
# Epoch #868, accuracy_rate=0.498
# Epoch #869, accuracy_rate=0.498
# Epoch #870, accuracy_rate=0.498
# Epoch #871, accuracy_rate=0.498
# Epoch #872, accuracy_rate=0.498
# Epoch #873, accuracy_rate=0.498
# Epoch #874, accuracy_rate=0.498
# Epoch #875, accuracy_rate=0.498
# Epoch #876, accuracy_rate=0.497
# Epoch #877, accuracy_rate=0.497
# Epoch #878, accuracy_rate=0.497
# Epoch #879, accuracy_rate=0.497
# Epoch #880, accuracy_rate=0.497
# Epoch #881, accuracy_rate=0.498
# Epoch #882, accuracy_rate=0.498
# Epoch #883, accuracy_rate=0.498
# Epoch #884, accuracy_rate=0.498
# Epoch #885, accuracy_rate=0.498
# Epoch #886, accuracy_rate=0.498
# Epoch #887, accuracy_rate=0.497
# Epoch #888, accuracy_rate=0.497
# Epoch #889, accuracy_rate=0.496
# Epoch #890, accuracy_rate=0.496
# Epoch #891, accuracy_rate=0.497
# Epoch #892, accuracy_rate=0.497
# Epoch #893, accuracy_rate=0.496
# Epoch #894, accuracy_rate=0.496
# Epoch #895, accuracy_rate=0.496
# Epoch #896, accuracy_rate=0.496
# Epoch #897, accuracy_rate=0.496
# Epoch #898, accuracy_rate=0.495
# Epoch #899, accuracy_rate=0.495
# Epoch #900, accuracy_rate=0.495
# Epoch #901, accuracy_rate=0.495
# Epoch #902, accuracy_rate=0.495
# Epoch #903, accuracy_rate=0.496
# Epoch #904, accuracy_rate=0.496
# Epoch #905, accuracy_rate=0.496
# Epoch #906, accuracy_rate=0.496
# Epoch #907, accuracy_rate=0.496
# Epoch #908, accuracy_rate=0.496
# Epoch #909, accuracy_rate=0.495
# Epoch #910, accuracy_rate=0.495
# Epoch #911, accuracy_rate=0.495
# Epoch #912, accuracy_rate=0.495
# Epoch #913, accuracy_rate=0.495
# Epoch #914, accuracy_rate=0.495
# Epoch #915, accuracy_rate=0.496
# Epoch #916, accuracy_rate=0.496
# Epoch #917, accuracy_rate=0.496
# Epoch #918, accuracy_rate=0.496
# Epoch #919, accuracy_rate=0.496
# Epoch #920, accuracy_rate=0.496
# Epoch #921, accuracy_rate=0.496
# Epoch #922, accuracy_rate=0.496
# Epoch #923, accuracy_rate=0.496
# Epoch #924, accuracy_rate=0.496
# Epoch #925, accuracy_rate=0.497
# Epoch #926, accuracy_rate=0.497
# Epoch #927, accuracy_rate=0.497
# Epoch #928, accuracy_rate=0.497
# Epoch #929, accuracy_rate=0.497
# Epoch #930, accuracy_rate=0.497
# Epoch #931, accuracy_rate=0.497
# Epoch #932, accuracy_rate=0.497
# Epoch #933, accuracy_rate=0.497
# Epoch #934, accuracy_rate=0.497
# Epoch #935, accuracy_rate=0.497
# Epoch #936, accuracy_rate=0.497
# Epoch #937, accuracy_rate=0.497
# Epoch #938, accuracy_rate=0.497
# Epoch #939, accuracy_rate=0.497
# Epoch #940, accuracy_rate=0.497
# Epoch #941, accuracy_rate=0.497
# Epoch #942, accuracy_rate=0.496
# Epoch #943, accuracy_rate=0.496
# Epoch #944, accuracy_rate=0.496
# Epoch #945, accuracy_rate=0.496
# Epoch #946, accuracy_rate=0.496
# Epoch #947, accuracy_rate=0.496
# Epoch #948, accuracy_rate=0.496
# Epoch #949, accuracy_rate=0.496
# Epoch #950, accuracy_rate=0.496
# Epoch #951, accuracy_rate=0.496
# Epoch #952, accuracy_rate=0.496
# Epoch #953, accuracy_rate=0.496
# Epoch #954, accuracy_rate=0.496
# Epoch #955, accuracy_rate=0.496
# Epoch #956, accuracy_rate=0.496
# Epoch #957, accuracy_rate=0.496
# Epoch #958, accuracy_rate=0.496
# Epoch #959, accuracy_rate=0.496
# Epoch #960, accuracy_rate=0.496
# Epoch #961, accuracy_rate=0.496
# Epoch #962, accuracy_rate=0.496
# Epoch #963, accuracy_rate=0.496
# Epoch #964, accuracy_rate=0.496
# Epoch #965, accuracy_rate=0.496
# Epoch #966, accuracy_rate=0.496
# Epoch #967, accuracy_rate=0.496
# Epoch #968, accuracy_rate=0.496
# Epoch #969, accuracy_rate=0.496
# Epoch #970, accuracy_rate=0.496
# Epoch #971, accuracy_rate=0.496
# Epoch #972, accuracy_rate=0.496
# Epoch #973, accuracy_rate=0.496
# Epoch #974, accuracy_rate=0.496
# Epoch #975, accuracy_rate=0.496
# Epoch #976, accuracy_rate=0.496
# Epoch #977, accuracy_rate=0.496
# Epoch #978, accuracy_rate=0.496
# Epoch #979, accuracy_rate=0.496
# Epoch #980, accuracy_rate=0.496
# Epoch #981, accuracy_rate=0.496
# Epoch #982, accuracy_rate=0.496
# Epoch #983, accuracy_rate=0.496
# Epoch #984, accuracy_rate=0.496
# Epoch #985, accuracy_rate=0.496
# Epoch #986, accuracy_rate=0.496
# Epoch #987, accuracy_rate=0.496
# Epoch #988, accuracy_rate=0.496
# Epoch #989, accuracy_rate=0.496
# Epoch #990, accuracy_rate=0.496
# Epoch #991, accuracy_rate=0.496
# Epoch #992, accuracy_rate=0.496
# Epoch #993, accuracy_rate=0.496
# Epoch #994, accuracy_rate=0.496
# Epoch #995, accuracy_rate=0.496
# Epoch #996, accuracy_rate=0.496
# Epoch #997, accuracy_rate=0.496
# Epoch #998, accuracy_rate=0.496
# Epoch #999, accuracy_rate=0.496
# Epoch #1000, accuracy_rate=0.496
# Epoch #1001, accuracy_rate=0.496
# Epoch #1002, accuracy_rate=0.496
# Epoch #1003, accuracy_rate=0.496
# Epoch #1004, accuracy_rate=0.496
# Epoch #1005, accuracy_rate=0.496
# Epoch #1006, accuracy_rate=0.496
# Epoch #1007, accuracy_rate=0.496
# Epoch #1008, accuracy_rate=0.496
# Epoch #1009, accuracy_rate=0.496
# Epoch #1010, accuracy_rate=0.496
# Epoch #1011, accuracy_rate=0.496
# Epoch #1012, accuracy_rate=0.496
# Epoch #1013, accuracy_rate=0.496
# Epoch #1014, accuracy_rate=0.495
# Epoch #1015, accuracy_rate=0.495
# Epoch #1016, accuracy_rate=0.495
# Epoch #1017, accuracy_rate=0.495
# Epoch #1018, accuracy_rate=0.495
# Epoch #1019, accuracy_rate=0.495
# Epoch #1020, accuracy_rate=0.495
# Epoch #1021, accuracy_rate=0.495
# Epoch #1022, accuracy_rate=0.495
# Epoch #1023, accuracy_rate=0.495
# Epoch #1024, accuracy_rate=0.495
# Epoch #1025, accuracy_rate=0.495
# Epoch #1026, accuracy_rate=0.495
# Epoch #1027, accuracy_rate=0.495
# Epoch #1028, accuracy_rate=0.495
# Epoch #1029, accuracy_rate=0.495
# Epoch #1030, accuracy_rate=0.495
# Epoch #1031, accuracy_rate=0.495
# Epoch #1032, accuracy_rate=0.495
# Epoch #1033, accuracy_rate=0.495
# Epoch #1034, accuracy_rate=0.495
# Epoch #1035, accuracy_rate=0.495
# Epoch #1036, accuracy_rate=0.495
# Epoch #1037, accuracy_rate=0.495
# Epoch #1038, accuracy_rate=0.495
# Epoch #1039, accuracy_rate=0.495
# Epoch #1040, accuracy_rate=0.495
# Epoch #1041, accuracy_rate=0.495
# Epoch #1042, accuracy_rate=0.495
# Epoch #1043, accuracy_rate=0.495
# Epoch #1044, accuracy_rate=0.495
# Epoch #1045, accuracy_rate=0.495
# Epoch #1046, accuracy_rate=0.495
# Epoch #1047, accuracy_rate=0.495
# Epoch #1048, accuracy_rate=0.495
# Epoch #1049, accuracy_rate=0.495
# Epoch #1050, accuracy_rate=0.495
# Epoch #1051, accuracy_rate=0.495
# Epoch #1052, accuracy_rate=0.495
# Epoch #1053, accuracy_rate=0.495
# Epoch #1054, accuracy_rate=0.495
# Epoch #1055, accuracy_rate=0.495
# Epoch #1056, accuracy_rate=0.495
# Epoch #1057, accuracy_rate=0.495
# Epoch #1058, accuracy_rate=0.495
# Epoch #1059, accuracy_rate=0.495
# Epoch #1060, accuracy_rate=0.495
# Epoch #1061, accuracy_rate=0.495
# Epoch #1062, accuracy_rate=0.495
# Epoch #1063, accuracy_rate=0.495
# Epoch #1064, accuracy_rate=0.495
# Epoch #1065, accuracy_rate=0.495
# Epoch #1066, accuracy_rate=0.495
# Epoch #1067, accuracy_rate=0.495
# Epoch #1068, accuracy_rate=0.495
# Epoch #1069, accuracy_rate=0.495
# Epoch #1070, accuracy_rate=0.495
# Epoch #1071, accuracy_rate=0.495
# Epoch #1072, accuracy_rate=0.495
# Epoch #1073, accuracy_rate=0.495
# Epoch #1074, accuracy_rate=0.495
# Epoch #1075, accuracy_rate=0.495
# Epoch #1076, accuracy_rate=0.495
# Epoch #1077, accuracy_rate=0.495
# Epoch #1078, accuracy_rate=0.495
# Epoch #1079, accuracy_rate=0.495
# Epoch #1080, accuracy_rate=0.495
# Epoch #1081, accuracy_rate=0.495
# Epoch #1082, accuracy_rate=0.495
# Epoch #1083, accuracy_rate=0.495
# Epoch #1084, accuracy_rate=0.495
# Epoch #1085, accuracy_rate=0.495
# Epoch #1086, accuracy_rate=0.495
# Epoch #1087, accuracy_rate=0.495
# Epoch #1088, accuracy_rate=0.495
# Epoch #1089, accuracy_rate=0.495
# Epoch #1090, accuracy_rate=0.495
# Epoch #1091, accuracy_rate=0.495
# Epoch #1092, accuracy_rate=0.495
# Epoch #1093, accuracy_rate=0.495
# Epoch #1094, accuracy_rate=0.495
# Epoch #1095, accuracy_rate=0.495
# Epoch #1096, accuracy_rate=0.495
# Epoch #1097, accuracy_rate=0.495
# Epoch #1098, accuracy_rate=0.495
# Epoch #1099, accuracy_rate=0.495
# Epoch #1100, accuracy_rate=0.495
# Epoch #1101, accuracy_rate=0.495
# Epoch #1102, accuracy_rate=0.495
# Epoch #1103, accuracy_rate=0.495
# Epoch #1104, accuracy_rate=0.495
# Epoch #1105, accuracy_rate=0.495
# Epoch #1106, accuracy_rate=0.495
# Epoch #1107, accuracy_rate=0.495
# Epoch #1108, accuracy_rate=0.495
# Epoch #1109, accuracy_rate=0.495
# Epoch #1110, accuracy_rate=0.495
# Epoch #1111, accuracy_rate=0.495
# Epoch #1112, accuracy_rate=0.495
# Epoch #1113, accuracy_rate=0.495
# Epoch #1114, accuracy_rate=0.495
# Epoch #1115, accuracy_rate=0.495
# Epoch #1116, accuracy_rate=0.495
# Epoch #1117, accuracy_rate=0.495
# Epoch #1118, accuracy_rate=0.495
# Epoch #1119, accuracy_rate=0.495
# Epoch #1120, accuracy_rate=0.495
# Epoch #1121, accuracy_rate=0.495
# Epoch #1122, accuracy_rate=0.495
# Epoch #1123, accuracy_rate=0.495
# Epoch #1124, accuracy_rate=0.495
# Epoch #1125, accuracy_rate=0.495
# Epoch #1126, accuracy_rate=0.495
# Epoch #1127, accuracy_rate=0.495
# Epoch #1128, accuracy_rate=0.495
# Epoch #1129, accuracy_rate=0.495
# Epoch #1130, accuracy_rate=0.495
# Epoch #1131, accuracy_rate=0.495
# Epoch #1132, accuracy_rate=0.495
# Epoch #1133, accuracy_rate=0.495
# Epoch #1134, accuracy_rate=0.495
# Epoch #1135, accuracy_rate=0.495
# Epoch #1136, accuracy_rate=0.495
# Epoch #1137, accuracy_rate=0.495
# Epoch #1138, accuracy_rate=0.495
# Epoch #1139, accuracy_rate=0.495
# Epoch #1140, accuracy_rate=0.495
# Epoch #1141, accuracy_rate=0.495
# Epoch #1142, accuracy_rate=0.495
# Epoch #1143, accuracy_rate=0.495
# Epoch #1144, accuracy_rate=0.495
# Epoch #1145, accuracy_rate=0.495
# Epoch #1146, accuracy_rate=0.495
# Epoch #1147, accuracy_rate=0.495
# Epoch #1148, accuracy_rate=0.495
# Epoch #1149, accuracy_rate=0.495
# Epoch #1150, accuracy_rate=0.495
# Epoch #1151, accuracy_rate=0.495
# Epoch #1152, accuracy_rate=0.495
# Epoch #1153, accuracy_rate=0.495
# Epoch #1154, accuracy_rate=0.495
# Epoch #1155, accuracy_rate=0.495
# Epoch #1156, accuracy_rate=0.495
# Epoch #1157, accuracy_rate=0.495
# Epoch #1158, accuracy_rate=0.495
# Epoch #1159, accuracy_rate=0.495
# Epoch #1160, accuracy_rate=0.495
# Epoch #1161, accuracy_rate=0.495
# Epoch #1162, accuracy_rate=0.495
# Epoch #1163, accuracy_rate=0.495
# Epoch #1164, accuracy_rate=0.495
# Epoch #1165, accuracy_rate=0.495
# Epoch #1166, accuracy_rate=0.495
# Epoch #1167, accuracy_rate=0.495
# Epoch #1168, accuracy_rate=0.495
# Epoch #1169, accuracy_rate=0.495
# Epoch #1170, accuracy_rate=0.495
# Epoch #1171, accuracy_rate=0.495
# Epoch #1172, accuracy_rate=0.495
# Epoch #1173, accuracy_rate=0.495
# Epoch #1174, accuracy_rate=0.495
# Epoch #1175, accuracy_rate=0.495
# Epoch #1176, accuracy_rate=0.495
# Epoch #1177, accuracy_rate=0.495
# Epoch #1178, accuracy_rate=0.495
# Epoch #1179, accuracy_rate=0.495
# Epoch #1180, accuracy_rate=0.495
# Epoch #1181, accuracy_rate=0.495
# Epoch #1182, accuracy_rate=0.495
# Epoch #1183, accuracy_rate=0.495
# Epoch #1184, accuracy_rate=0.495
# Epoch #1185, accuracy_rate=0.495
# Epoch #1186, accuracy_rate=0.495
# Epoch #1187, accuracy_rate=0.495
# Epoch #1188, accuracy_rate=0.495
# Epoch #1189, accuracy_rate=0.495
# Epoch #1190, accuracy_rate=0.495
# Epoch #1191, accuracy_rate=0.495
# Epoch #1192, accuracy_rate=0.495
# Epoch #1193, accuracy_rate=0.495
# Epoch #1194, accuracy_rate=0.495
# Epoch #1195, accuracy_rate=0.495
# Epoch #1196, accuracy_rate=0.495
# Epoch #1197, accuracy_rate=0.495
# Epoch #1198, accuracy_rate=0.495
# Epoch #1199, accuracy_rate=0.495
# Epoch #1200, accuracy_rate=0.495
# Epoch #1201, accuracy_rate=0.495
# Epoch #1202, accuracy_rate=0.495
# Epoch #1203, accuracy_rate=0.496
# Epoch #1204, accuracy_rate=0.495
# Epoch #1205, accuracy_rate=0.495
# Epoch #1206, accuracy_rate=0.495
# Epoch #1207, accuracy_rate=0.495
# Epoch #1208, accuracy_rate=0.495
# Epoch #1209, accuracy_rate=0.495
# Epoch #1210, accuracy_rate=0.495
# Epoch #1211, accuracy_rate=0.495
# Epoch #1212, accuracy_rate=0.495
# Epoch #1213, accuracy_rate=0.495
# Epoch #1214, accuracy_rate=0.495
# Epoch #1215, accuracy_rate=0.495
# Epoch #1216, accuracy_rate=0.495
# Epoch #1217, accuracy_rate=0.495
# Epoch #1218, accuracy_rate=0.495
# Epoch #1219, accuracy_rate=0.495
# Epoch #1220, accuracy_rate=0.495
# Epoch #1221, accuracy_rate=0.495
# Epoch #1222, accuracy_rate=0.495
# Epoch #1223, accuracy_rate=0.495
# Epoch #1224, accuracy_rate=0.495
# Epoch #1225, accuracy_rate=0.495
# Epoch #1226, accuracy_rate=0.495
# Epoch #1227, accuracy_rate=0.495
# Epoch #1228, accuracy_rate=0.495
# Epoch #1229, accuracy_rate=0.495
# Epoch #1230, accuracy_rate=0.495
# Epoch #1231, accuracy_rate=0.495
# Epoch #1232, accuracy_rate=0.495
# Epoch #1233, accuracy_rate=0.495
# Epoch #1234, accuracy_rate=0.495
# Epoch #1235, accuracy_rate=0.495
# Epoch #1236, accuracy_rate=0.495
# Epoch #1237, accuracy_rate=0.496
# Epoch #1238, accuracy_rate=0.495
# Epoch #1239, accuracy_rate=0.495
# Epoch #1240, accuracy_rate=0.495
# Epoch #1241, accuracy_rate=0.496
# Epoch #1242, accuracy_rate=0.495
# Epoch #1243, accuracy_rate=0.495
# Epoch #1244, accuracy_rate=0.496
# Epoch #1245, accuracy_rate=0.495
# Epoch #1246, accuracy_rate=0.495
# Epoch #1247, accuracy_rate=0.495
# Epoch #1248, accuracy_rate=0.496
# Epoch #1249, accuracy_rate=0.495
# Epoch #1250, accuracy_rate=0.495
# Epoch #1251, accuracy_rate=0.496
# Epoch #1252, accuracy_rate=0.495
# Epoch #1253, accuracy_rate=0.495
# Epoch #1254, accuracy_rate=0.495
# Epoch #1255, accuracy_rate=0.496
# Epoch #1256, accuracy_rate=0.495
# Epoch #1257, accuracy_rate=0.495
# Epoch #1258, accuracy_rate=0.495
# Epoch #1259, accuracy_rate=0.496
# Epoch #1260, accuracy_rate=0.495
# Epoch #1261, accuracy_rate=0.495
# Epoch #1262, accuracy_rate=0.496
# Epoch #1263, accuracy_rate=0.495
# Epoch #1264, accuracy_rate=0.495
# Epoch #1265, accuracy_rate=0.495
# Epoch #1266, accuracy_rate=0.496
# Epoch #1267, accuracy_rate=0.495
# Epoch #1268, accuracy_rate=0.495
# Epoch #1269, accuracy_rate=0.496
# Epoch #1270, accuracy_rate=0.495
# Epoch #1271, accuracy_rate=0.495
# Epoch #1272, accuracy_rate=0.495
# Epoch #1273, accuracy_rate=0.496
# Epoch #1274, accuracy_rate=0.495
# Epoch #1275, accuracy_rate=0.495
# Epoch #1276, accuracy_rate=0.496
# Epoch #1277, accuracy_rate=0.496
# Epoch #1278, accuracy_rate=0.496
# Epoch #1279, accuracy_rate=0.496
# Epoch #1280, accuracy_rate=0.496
# Epoch #1281, accuracy_rate=0.496
# Epoch #1282, accuracy_rate=0.496
# Epoch #1283, accuracy_rate=0.496
# Epoch #1284, accuracy_rate=0.496
# Epoch #1285, accuracy_rate=0.496
# Epoch #1286, accuracy_rate=0.496
# Epoch #1287, accuracy_rate=0.496
# Epoch #1288, accuracy_rate=0.496
# Epoch #1289, accuracy_rate=0.496
# Epoch #1290, accuracy_rate=0.496
# Epoch #1291, accuracy_rate=0.496
# Epoch #1292, accuracy_rate=0.496
# Epoch #1293, accuracy_rate=0.496
# Epoch #1294, accuracy_rate=0.496
# Epoch #1295, accuracy_rate=0.496
# Epoch #1296, accuracy_rate=0.496
# Epoch #1297, accuracy_rate=0.496
# Epoch #1298, accuracy_rate=0.496
# Epoch #1299, accuracy_rate=0.496
# Epoch #1300, accuracy_rate=0.496
# Epoch #1301, accuracy_rate=0.496
# Epoch #1302, accuracy_rate=0.496
# Epoch #1303, accuracy_rate=0.496
# Epoch #1304, accuracy_rate=0.496
# Epoch #1305, accuracy_rate=0.496
# Epoch #1306, accuracy_rate=0.496
# Epoch #1307, accuracy_rate=0.496
# Epoch #1308, accuracy_rate=0.496
# Epoch #1309, accuracy_rate=0.496
# Epoch #1310, accuracy_rate=0.496
# Epoch #1311, accuracy_rate=0.496
# Epoch #1312, accuracy_rate=0.496
# Epoch #1313, accuracy_rate=0.496
# Epoch #1314, accuracy_rate=0.496
# Epoch #1315, accuracy_rate=0.497
# Epoch #1316, accuracy_rate=0.497
# Epoch #1317, accuracy_rate=0.497
# Epoch #1318, accuracy_rate=0.497
# Epoch #1319, accuracy_rate=0.497
# Epoch #1320, accuracy_rate=0.497
# Epoch #1321, accuracy_rate=0.497
# Epoch #1322, accuracy_rate=0.497
# Epoch #1323, accuracy_rate=0.497
# Epoch #1324, accuracy_rate=0.497
# Epoch #1325, accuracy_rate=0.497
# Epoch #1326, accuracy_rate=0.497
# Epoch #1327, accuracy_rate=0.497
# Epoch #1328, accuracy_rate=0.497
# Epoch #1329, accuracy_rate=0.497
# Epoch #1330, accuracy_rate=0.497
# Epoch #1331, accuracy_rate=0.497
# Epoch #1332, accuracy_rate=0.497
# Epoch #1333, accuracy_rate=0.497
# Epoch #1334, accuracy_rate=0.497
# Epoch #1335, accuracy_rate=0.497
# Epoch #1336, accuracy_rate=0.497
# Epoch #1337, accuracy_rate=0.497
# Epoch #1338, accuracy_rate=0.497
# Epoch #1339, accuracy_rate=0.497
# Epoch #1340, accuracy_rate=0.497
# Epoch #1341, accuracy_rate=0.497
# Epoch #1342, accuracy_rate=0.497
# Epoch #1343, accuracy_rate=0.497
# Epoch #1344, accuracy_rate=0.497
# Epoch #1345, accuracy_rate=0.497
# Epoch #1346, accuracy_rate=0.497
# Epoch #1347, accuracy_rate=0.497
# Epoch #1348, accuracy_rate=0.497
# Epoch #1349, accuracy_rate=0.497
# Epoch #1350, accuracy_rate=0.497
# Epoch #1351, accuracy_rate=0.497
# Epoch #1352, accuracy_rate=0.497
# Epoch #1353, accuracy_rate=0.497
# Epoch #1354, accuracy_rate=0.497
# Epoch #1355, accuracy_rate=0.497
# Epoch #1356, accuracy_rate=0.497
# Epoch #1357, accuracy_rate=0.497
# Epoch #1358, accuracy_rate=0.497
# Epoch #1359, accuracy_rate=0.497
# Epoch #1360, accuracy_rate=0.497
# Epoch #1361, accuracy_rate=0.497
# Epoch #1362, accuracy_rate=0.497
# Epoch #1363, accuracy_rate=0.497
# Epoch #1364, accuracy_rate=0.497
# Epoch #1365, accuracy_rate=0.497
# Epoch #1366, accuracy_rate=0.497
# Epoch #1367, accuracy_rate=0.497
# Epoch #1368, accuracy_rate=0.497
# Epoch #1369, accuracy_rate=0.497
# Epoch #1370, accuracy_rate=0.497
# Epoch #1371, accuracy_rate=0.497
# Epoch #1372, accuracy_rate=0.497
# Epoch #1373, accuracy_rate=0.497
# Epoch #1374, accuracy_rate=0.497
# Epoch #1375, accuracy_rate=0.497
# Epoch #1376, accuracy_rate=0.497
# Epoch #1377, accuracy_rate=0.497
# Epoch #1378, accuracy_rate=0.497
# Epoch #1379, accuracy_rate=0.497
# Epoch #1380, accuracy_rate=0.497
# Epoch #1381, accuracy_rate=0.497
# Epoch #1382, accuracy_rate=0.497
# Epoch #1383, accuracy_rate=0.497
# Epoch #1384, accuracy_rate=0.497
# Epoch #1385, accuracy_rate=0.497
# Epoch #1386, accuracy_rate=0.497
# Epoch #1387, accuracy_rate=0.497
# Epoch #1388, accuracy_rate=0.497
# Epoch #1389, accuracy_rate=0.497
# Epoch #1390, accuracy_rate=0.497
# Epoch #1391, accuracy_rate=0.497
# Epoch #1392, accuracy_rate=0.497
# Epoch #1393, accuracy_rate=0.498
# Epoch #1394, accuracy_rate=0.497
# Epoch #1395, accuracy_rate=0.498
# Epoch #1396, accuracy_rate=0.497
# Epoch #1397, accuracy_rate=0.498
# Epoch #1398, accuracy_rate=0.498
# Epoch #1399, accuracy_rate=0.497
# Epoch #1400, accuracy_rate=0.498
# Epoch #1401, accuracy_rate=0.498
# Epoch #1402, accuracy_rate=0.497
# Epoch #1403, accuracy_rate=0.498
# Epoch #1404, accuracy_rate=0.498
# Epoch #1405, accuracy_rate=0.497
# Epoch #1406, accuracy_rate=0.498
# Epoch #1407, accuracy_rate=0.498
# Epoch #1408, accuracy_rate=0.497
# Epoch #1409, accuracy_rate=0.498
# Epoch #1410, accuracy_rate=0.498
# Epoch #1411, accuracy_rate=0.497
# Epoch #1412, accuracy_rate=0.498
# Epoch #1413, accuracy_rate=0.497
# Epoch #1414, accuracy_rate=0.498
# Epoch #1415, accuracy_rate=0.498
# Epoch #1416, accuracy_rate=0.497
# Epoch #1417, accuracy_rate=0.498
# Epoch #1418, accuracy_rate=0.498
# Epoch #1419, accuracy_rate=0.497
# Epoch #1420, accuracy_rate=0.498
# Epoch #1421, accuracy_rate=0.498
# Epoch #1422, accuracy_rate=0.497
# Epoch #1423, accuracy_rate=0.498
# Epoch #1424, accuracy_rate=0.498
# Epoch #1425, accuracy_rate=0.497
# Epoch #1426, accuracy_rate=0.498
# Epoch #1427, accuracy_rate=0.497
# Epoch #1428, accuracy_rate=0.498
# Epoch #1429, accuracy_rate=0.498
# Epoch #1430, accuracy_rate=0.497
# Epoch #1431, accuracy_rate=0.498
# Epoch #1432, accuracy_rate=0.498
# Epoch #1433, accuracy_rate=0.497
# Epoch #1434, accuracy_rate=0.498
# Epoch #1435, accuracy_rate=0.498
# Epoch #1436, accuracy_rate=0.497
# Epoch #1437, accuracy_rate=0.498
# Epoch #1438, accuracy_rate=0.498
# Epoch #1439, accuracy_rate=0.497
# Epoch #1440, accuracy_rate=0.498
# Epoch #1441, accuracy_rate=0.497
# Epoch #1442, accuracy_rate=0.498
# Epoch #1443, accuracy_rate=0.498
# Epoch #1444, accuracy_rate=0.497
# Epoch #1445, accuracy_rate=0.498
# Epoch #1446, accuracy_rate=0.498
# Epoch #1447, accuracy_rate=0.498
# Epoch #1448, accuracy_rate=0.498
# Epoch #1449, accuracy_rate=0.498
# Epoch #1450, accuracy_rate=0.498
# Epoch #1451, accuracy_rate=0.498
# Epoch #1452, accuracy_rate=0.498
# Epoch #1453, accuracy_rate=0.498
# Epoch #1454, accuracy_rate=0.498
# Epoch #1455, accuracy_rate=0.498
# Epoch #1456, accuracy_rate=0.498
# Epoch #1457, accuracy_rate=0.498
# Epoch #1458, accuracy_rate=0.498
# Epoch #1459, accuracy_rate=0.498
# Epoch #1460, accuracy_rate=0.498
# Epoch #1461, accuracy_rate=0.498
# Epoch #1462, accuracy_rate=0.498
# Epoch #1463, accuracy_rate=0.498
# Epoch #1464, accuracy_rate=0.498
# Epoch #1465, accuracy_rate=0.498
# Epoch #1466, accuracy_rate=0.498
# Epoch #1467, accuracy_rate=0.498
# Epoch #1468, accuracy_rate=0.498
# Epoch #1469, accuracy_rate=0.498
# Epoch #1470, accuracy_rate=0.498
# Epoch #1471, accuracy_rate=0.498
# Epoch #1472, accuracy_rate=0.498
# Epoch #1473, accuracy_rate=0.498
# Epoch #1474, accuracy_rate=0.498
# Epoch #1475, accuracy_rate=0.498
# Epoch #1476, accuracy_rate=0.498
# Epoch #1477, accuracy_rate=0.498
# Epoch #1478, accuracy_rate=0.498
# Epoch #1479, accuracy_rate=0.498
# Epoch #1480, accuracy_rate=0.498
# Epoch #1481, accuracy_rate=0.498
# Epoch #1482, accuracy_rate=0.498
# Epoch #1483, accuracy_rate=0.498
# Epoch #1484, accuracy_rate=0.498
# Epoch #1485, accuracy_rate=0.499
# Epoch #1486, accuracy_rate=0.498
# Epoch #1487, accuracy_rate=0.499
# ...
# Epoch #6519, accuracy_rate=0.323
# Epoch #6520, accuracy_rate=0.677
# Epoch #6521, accuracy_rate=0.323
# Epoch #6522, accuracy_rate=0.677
# Epoch #6523, accuracy_rate=0.323
# Epoch #6524, accuracy_rate=0.677
# Epoch #6525, accuracy_rate=0.323
# Epoch #6526, accuracy_rate=0.677
# Epoch #6527, accuracy_rate=0.323
# Epoch #6528, accuracy_rate=0.677
# Epoch #6529, accuracy_rate=0.323
# Epoch #6530, accuracy_rate=0.677
# Epoch #6531, accuracy_rate=0.323
# Epoch #6532, accuracy_rate=0.677
# Epoch #6533, accuracy_rate=0.323
# Epoch #6534, accuracy_rate=0.677
# Epoch #6535, accuracy_rate=0.323
# Epoch #6536, accuracy_rate=0.677
# Epoch #6537, accuracy_rate=0.323
# Epoch #6538, accuracy_rate=0.677
# Epoch #6539, accuracy_rate=0.323
# Epoch #6540, accuracy_rate=0.677
# Epoch #6541, accuracy_rate=0.323
# Epoch #6542, accuracy_rate=0.677
# Epoch #6543, accuracy_rate=0.323
# Epoch #6544, accuracy_rate=0.677
# Epoch #6545, accuracy_rate=0.323
# Epoch #6546, accuracy_rate=0.677
# Epoch #6547, accuracy_rate=0.323
# Epoch #6548, accuracy_rate=0.677
# Epoch #6549, accuracy_rate=0.323
# Epoch #6550, accuracy_rate=0.677
# Epoch #6551, accuracy_rate=0.323
# Epoch #6552, accuracy_rate=0.677
# Epoch #6553, accuracy_rate=0.323
# Epoch #6554, accuracy_rate=0.677
# Epoch #6555, accuracy_rate=0.323
# Epoch #6556, accuracy_rate=0.677
# Epoch #6557, accuracy_rate=0.323
# Epoch #6558, accuracy_rate=0.677
# Epoch #6559, accuracy_rate=0.323
# Epoch #6560, accuracy_rate=0.677
# Epoch #6561, accuracy_rate=0.323
# Epoch #6562, accuracy_rate=0.677
# Epoch #6563, accuracy_rate=0.323
# Epoch #6564, accuracy_rate=0.677
# Epoch #6565, accuracy_rate=0.323
# Epoch #6566, accuracy_rate=0.677
# Epoch #6567, accuracy_rate=0.323
# Epoch #6568, accuracy_rate=0.677
# Epoch #6569, accuracy_rate=0.323
# Epoch #6570, accuracy_rate=0.677
# Epoch #6571, accuracy_rate=0.323
# Epoch #6572, accuracy_rate=0.677
# Epoch #6573, accuracy_rate=0.323
# Epoch #6574, accuracy_rate=0.677
# Epoch #6575, accuracy_rate=0.323
# Epoch #6576, accuracy_rate=0.677
# Epoch #6577, accuracy_rate=0.323
# Epoch #6578, accuracy_rate=0.677
# Epoch #6579, accuracy_rate=0.323
# Epoch #6580, accuracy_rate=0.677
# Epoch #6581, accuracy_rate=0.323
# Epoch #6582, accuracy_rate=0.677
# Epoch #6583, accuracy_rate=0.323
# Epoch #6584, accuracy_rate=0.677
# Epoch #6585, accuracy_rate=0.323
# Epoch #6586, accuracy_rate=0.677
# Epoch #6587, accuracy_rate=0.323
# Epoch #6588, accuracy_rate=0.677
# Epoch #6589, accuracy_rate=0.323
# Epoch #6590, accuracy_rate=0.677
# Epoch #6591, accuracy_rate=0.323
# Epoch #6592, accuracy_rate=0.677
# Epoch #6593, accuracy_rate=0.323
# Epoch #6594, accuracy_rate=0.677
# Epoch #6595, accuracy_rate=0.323
# Epoch #6596, accuracy_rate=0.677
# Epoch #6597, accuracy_rate=0.323
# Epoch #6598, accuracy_rate=0.677
# Epoch #6599, accuracy_rate=0.323
# Epoch #6600, accuracy_rate=0.677
# Epoch #6601, accuracy_rate=0.323
# Epoch #6602, accuracy_rate=0.677
# Epoch #6603, accuracy_rate=0.323
# Epoch #6604, accuracy_rate=0.677
# Epoch #6605, accuracy_rate=0.323
# Epoch #6606, accuracy_rate=0.677
# Epoch #6607, accuracy_rate=0.323
# Epoch #6608, accuracy_rate=0.677
# Epoch #6609, accuracy_rate=0.323
# Epoch #6610, accuracy_rate=0.677
# Epoch #6611, accuracy_rate=0.323
# Epoch #6612, accuracy_rate=0.677
# Epoch #6613, accuracy_rate=0.323
# Epoch #6614, accuracy_rate=0.677
# Epoch #6615, accuracy_rate=0.323
# Epoch #6616, accuracy_rate=0.677
# Epoch #6617, accuracy_rate=0.323
# Epoch #6618, accuracy_rate=0.677
# Epoch #6619, accuracy_rate=0.323
# Epoch #6620, accuracy_rate=0.677
# Epoch #6621, accuracy_rate=0.323
# Epoch #6622, accuracy_rate=0.677
# Epoch #6623, accuracy_rate=0.323
# Epoch #6624, accuracy_rate=0.677
# Epoch #6625, accuracy_rate=0.323
# Epoch #6626, accuracy_rate=0.677
# Epoch #6627, accuracy_rate=0.323
# Epoch #6628, accuracy_rate=0.677
# Epoch #6629, accuracy_rate=0.323
# Epoch #6630, accuracy_rate=0.677
# Epoch #6631, accuracy_rate=0.323
# Epoch #6632, accuracy_rate=0.677
# Epoch #6633, accuracy_rate=0.323
# Epoch #6634, accuracy_rate=0.677
# Epoch #6635, accuracy_rate=0.323
# Epoch #6636, accuracy_rate=0.677
# Epoch #6637, accuracy_rate=0.323
# Epoch #6638, accuracy_rate=0.677
# Epoch #6639, accuracy_rate=0.323
# Epoch #6640, accuracy_rate=0.677
# Epoch #6641, accuracy_rate=0.323
# Epoch #6642, accuracy_rate=0.677
# Epoch #6643, accuracy_rate=0.323
# Epoch #6644, accuracy_rate=0.677
# Epoch #6645, accuracy_rate=0.323
# Epoch #6646, accuracy_rate=0.677
# Epoch #6647, accuracy_rate=0.323
# Epoch #6648, accuracy_rate=0.677
# Epoch #6649, accuracy_rate=0.323
# Epoch #6650, accuracy_rate=0.677
# Epoch #6651, accuracy_rate=0.323
# Epoch #6652, accuracy_rate=0.677
# Epoch #6653, accuracy_rate=0.323
# Epoch #6654, accuracy_rate=0.677
# Epoch #6655, accuracy_rate=0.323
# Epoch #6656, accuracy_rate=0.677
# Epoch #6657, accuracy_rate=0.323
# Epoch #6658, accuracy_rate=0.677
# Epoch #6659, accuracy_rate=0.323
# Epoch #6660, accuracy_rate=0.677
# Epoch #6661, accuracy_rate=0.323
# Epoch #6662, accuracy_rate=0.677
# Epoch #6663, accuracy_rate=0.323
# Epoch #6664, accuracy_rate=0.677
# Epoch #6665, accuracy_rate=0.323
# Epoch #6666, accuracy_rate=0.677
# Epoch #6667, accuracy_rate=0.323
# Epoch #6668, accuracy_rate=0.677
# Epoch #6669, accuracy_rate=0.323
# Epoch #6670, accuracy_rate=0.677
# Epoch #6671, accuracy_rate=0.323
# Epoch #6672, accuracy_rate=0.677
# Epoch #6673, accuracy_rate=0.323
# Epoch #6674, accuracy_rate=0.677
# Epoch #6675, accuracy_rate=0.323
# Epoch #6676, accuracy_rate=0.677
# Epoch #6677, accuracy_rate=0.323
# Epoch #6678, accuracy_rate=0.677
# Epoch #6679, accuracy_rate=0.323
# Epoch #6680, accuracy_rate=0.677
# Epoch #6681, accuracy_rate=0.323
# Epoch #6682, accuracy_rate=0.677
# Epoch #6683, accuracy_rate=0.323
# Epoch #6684, accuracy_rate=0.677
# Epoch #6685, accuracy_rate=0.323
# Epoch #6686, accuracy_rate=0.677
# Epoch #6687, accuracy_rate=0.323
# Epoch #6688, accuracy_rate=0.677
# Epoch #6689, accuracy_rate=0.323
# Epoch #6690, accuracy_rate=0.677
# Epoch #6691, accuracy_rate=0.323
# Epoch #6692, accuracy_rate=0.677
# Epoch #6693, accuracy_rate=0.323
# Epoch #6694, accuracy_rate=0.677
# Epoch #6695, accuracy_rate=0.323
# Epoch #6696, accuracy_rate=0.677
# Epoch #6697, accuracy_rate=0.323
# Epoch #6698, accuracy_rate=0.677
# Epoch #6699, accuracy_rate=0.323
# Epoch #6700, accuracy_rate=0.677
# Epoch #6701, accuracy_rate=0.323
# Epoch #6702, accuracy_rate=0.677
# Epoch #6703, accuracy_rate=0.323
# Epoch #6704, accuracy_rate=0.677
# Epoch #6705, accuracy_rate=0.323
# Epoch #6706, accuracy_rate=0.677
# Epoch #6707, accuracy_rate=0.323
# Epoch #6708, accuracy_rate=0.677
# Epoch #6709, accuracy_rate=0.323
# Epoch #6710, accuracy_rate=0.677
# Epoch #6711, accuracy_rate=0.323
# Epoch #6712, accuracy_rate=0.677
# Epoch #6713, accuracy_rate=0.323
# Epoch #6714, accuracy_rate=0.677
# Epoch #6715, accuracy_rate=0.323
# Epoch #6716, accuracy_rate=0.677
# Epoch #6717, accuracy_rate=0.323
# Epoch #6718, accuracy_rate=0.677
# Epoch #6719, accuracy_rate=0.323
# Epoch #6720, accuracy_rate=0.677
# Epoch #6721, accuracy_rate=0.323
# Epoch #6722, accuracy_rate=0.677
# Epoch #6723, accuracy_rate=0.323
# Epoch #6724, accuracy_rate=0.677
# Epoch #6725, accuracy_rate=0.323
# Epoch #6726, accuracy_rate=0.677
# Epoch #6727, accuracy_rate=0.323
# Epoch #6728, accuracy_rate=0.677
# Epoch #6729, accuracy_rate=0.323
# Epoch #6730, accuracy_rate=0.677
# Epoch #6731, accuracy_rate=0.323
# Epoch #6732, accuracy_rate=0.677
# Epoch #6733, accuracy_rate=0.323
# Epoch #6734, accuracy_rate=0.677
# Epoch #6735, accuracy_rate=0.323
# Epoch #6736, accuracy_rate=0.677
# Epoch #6737, accuracy_rate=0.323
# Epoch #6738, accuracy_rate=0.677
# Epoch #6739, accuracy_rate=0.323
# Epoch #6740, accuracy_rate=0.677
# Epoch #6741, accuracy_rate=0.323
# Epoch #6742, accuracy_rate=0.677
# Epoch #6743, accuracy_rate=0.323
# Epoch #6744, accuracy_rate=0.677
# Epoch #6745, accuracy_rate=0.323
# Epoch #6746, accuracy_rate=0.677
# Epoch #6747, accuracy_rate=0.323
# Epoch #6748, accuracy_rate=0.677
# Epoch #6749, accuracy_rate=0.323
# Epoch #6750, accuracy_rate=0.677
# Epoch #6751, accuracy_rate=0.323
# Epoch #6752, accuracy_rate=0.677
# Epoch #6753, accuracy_rate=0.323
# Epoch #6754, accuracy_rate=0.677
# Epoch #6755, accuracy_rate=0.323
# Epoch #6756, accuracy_rate=0.677
# Epoch #6757, accuracy_rate=0.323
# Epoch #6758, accuracy_rate=0.677
# Epoch #6759, accuracy_rate=0.323
# Epoch #6760, accuracy_rate=0.677
# Epoch #6761, accuracy_rate=0.323
# Epoch #6762, accuracy_rate=0.677
# Epoch #6763, accuracy_rate=0.323
# Epoch #6764, accuracy_rate=0.677
# Epoch #6765, accuracy_rate=0.323
# Epoch #6766, accuracy_rate=0.677
# Epoch #6767, accuracy_rate=0.323
# Epoch #6768, accuracy_rate=0.677
# Epoch #6769, accuracy_rate=0.323
# Epoch #6770, accuracy_rate=0.677
# Epoch #6771, accuracy_rate=0.323
# Epoch #6772, accuracy_rate=0.677
# Epoch #6773, accuracy_rate=0.323
# Epoch #6774, accuracy_rate=0.677
# Epoch #6775, accuracy_rate=0.323
# Epoch #6776, accuracy_rate=0.677
# Epoch #6777, accuracy_rate=0.323
# Epoch #6778, accuracy_rate=0.677
# Epoch #6779, accuracy_rate=0.323
# Epoch #6780, accuracy_rate=0.677
# Epoch #6781, accuracy_rate=0.323
# Epoch #6782, accuracy_rate=0.677
# Epoch #6783, accuracy_rate=0.323
# Epoch #6784, accuracy_rate=0.677
# Epoch #6785, accuracy_rate=0.323
# Epoch #6786, accuracy_rate=0.677
# Epoch #6787, accuracy_rate=0.323
# Epoch #6788, accuracy_rate=0.677
# Epoch #6789, accuracy_rate=0.323
# Epoch #6790, accuracy_rate=0.677
# Epoch #6791, accuracy_rate=0.323
# Epoch #6792, accuracy_rate=0.677
# Epoch #6793, accuracy_rate=0.323
# Epoch #6794, accuracy_rate=0.677
# Epoch #6795, accuracy_rate=0.323
# Epoch #6796, accuracy_rate=0.677
# Epoch #6797, accuracy_rate=0.323
# Epoch #6798, accuracy_rate=0.677
# Epoch #6799, accuracy_rate=0.323
# Epoch #6800, accuracy_rate=0.677
# Epoch #6801, accuracy_rate=0.323
# Epoch #6802, accuracy_rate=0.677
# Epoch #6803, accuracy_rate=0.323
# Epoch #6804, accuracy_rate=0.677
# Epoch #6805, accuracy_rate=0.323
# Epoch #6806, accuracy_rate=0.677
# Epoch #6807, accuracy_rate=0.323
# Epoch #6808, accuracy_rate=0.677
# Epoch #6809, accuracy_rate=0.323
# Epoch #6810, accuracy_rate=0.677
# Epoch #6811, accuracy_rate=0.323
# Epoch #6812, accuracy_rate=0.677
# Epoch #6813, accuracy_rate=0.323
# Epoch #6814, accuracy_rate=0.677
# Epoch #6815, accuracy_rate=0.323
# Epoch #6816, accuracy_rate=0.677
# Epoch #6817, accuracy_rate=0.323
# Epoch #6818, accuracy_rate=0.677
# Epoch #6819, accuracy_rate=0.323
# Epoch #6820, accuracy_rate=0.677
# Epoch #6821, accuracy_rate=0.323
# Epoch #6822, accuracy_rate=0.677
# Epoch #6823, accuracy_rate=0.323
# Epoch #6824, accuracy_rate=0.677
# Epoch #6825, accuracy_rate=0.323
# Epoch #6826, accuracy_rate=0.677
# Epoch #6827, accuracy_rate=0.323
# Epoch #6828, accuracy_rate=0.677
# Epoch #6829, accuracy_rate=0.323
# Epoch #6830, accuracy_rate=0.677
# Epoch #6831, accuracy_rate=0.323
# Epoch #6832, accuracy_rate=0.677
# Epoch #6833, accuracy_rate=0.323
# Epoch #6834, accuracy_rate=0.677
# Epoch #6835, accuracy_rate=0.323
# Epoch #6836, accuracy_rate=0.677
# Epoch #6837, accuracy_rate=0.323
# Epoch #6838, accuracy_rate=0.677
# Epoch #6839, accuracy_rate=0.323
# Epoch #6840, accuracy_rate=0.677
# Epoch #6841, accuracy_rate=0.323
# Epoch #6842, accuracy_rate=0.677
# Epoch #6843, accuracy_rate=0.323
# Epoch #6844, accuracy_rate=0.677
# Epoch #6845, accuracy_rate=0.323
# Epoch #6846, accuracy_rate=0.677
# Epoch #6847, accuracy_rate=0.323
# Epoch #6848, accuracy_rate=0.677
# Epoch #6849, accuracy_rate=0.323
# Epoch #6850, accuracy_rate=0.677
# Epoch #6851, accuracy_rate=0.323
# Epoch #6852, accuracy_rate=0.677
# Epoch #6853, accuracy_rate=0.323
# Epoch #6854, accuracy_rate=0.677
# Epoch #6855, accuracy_rate=0.323
# Epoch #6856, accuracy_rate=0.677
# Epoch #6857, accuracy_rate=0.323
# Epoch #6858, accuracy_rate=0.677
# Epoch #6859, accuracy_rate=0.323
# Epoch #6860, accuracy_rate=0.677
# Epoch #6861, accuracy_rate=0.323
# Epoch #6862, accuracy_rate=0.677
# Epoch #6863, accuracy_rate=0.323
# Epoch #6864, accuracy_rate=0.677
# Epoch #6865, accuracy_rate=0.323
# Epoch #6866, accuracy_rate=0.677
# Epoch #6867, accuracy_rate=0.323
# Epoch #6868, accuracy_rate=0.677
# Epoch #6869, accuracy_rate=0.323
# Epoch #6870, accuracy_rate=0.677
# Epoch #6871, accuracy_rate=0.323
# Epoch #6872, accuracy_rate=0.677
# Epoch #6873, accuracy_rate=0.323
# Epoch #6874, accuracy_rate=0.677
# Epoch #6875, accuracy_rate=0.323
# Epoch #6876, accuracy_rate=0.677
# Epoch #6877, accuracy_rate=0.323
# Epoch #6878, accuracy_rate=0.677
# Epoch #6879, accuracy_rate=0.323
# Epoch #6880, accuracy_rate=0.677
# Epoch #6881, accuracy_rate=0.323
# Epoch #6882, accuracy_rate=0.677
# Epoch #6883, accuracy_rate=0.323
# Epoch #6884, accuracy_rate=0.677
# Epoch #6885, accuracy_rate=0.323
# Epoch #6886, accuracy_rate=0.677
# Epoch #6887, accuracy_rate=0.323
# Epoch #6888, accuracy_rate=0.677
# Epoch #6889, accuracy_rate=0.323
# Epoch #6890, accuracy_rate=0.677
# Epoch #6891, accuracy_rate=0.323
# Epoch #6892, accuracy_rate=0.677
# Epoch #6893, accuracy_rate=0.323
# Epoch #6894, accuracy_rate=0.677
# Epoch #6895, accuracy_rate=0.323
# Epoch #6896, accuracy_rate=0.677
# Epoch #6897, accuracy_rate=0.323
# Epoch #6898, accuracy_rate=0.677
# Epoch #6899, accuracy_rate=0.323
# Epoch #6900, accuracy_rate=0.677
# Epoch #6901, accuracy_rate=0.323
# Epoch #6902, accuracy_rate=0.677
# Epoch #6903, accuracy_rate=0.323
# Epoch #6904, accuracy_rate=0.677
# Epoch #6905, accuracy_rate=0.323
# Epoch #6906, accuracy_rate=0.677
# Epoch #6907, accuracy_rate=0.323
# Epoch #6908, accuracy_rate=0.677
# Epoch #6909, accuracy_rate=0.323
# Epoch #6910, accuracy_rate=0.677
# Epoch #6911, accuracy_rate=0.323
# Epoch #6912, accuracy_rate=0.677
# Epoch #6913, accuracy_rate=0.323
# Epoch #6914, accuracy_rate=0.677
# Epoch #6915, accuracy_rate=0.323
# Epoch #6916, accuracy_rate=0.677
# Epoch #6917, accuracy_rate=0.323
# Epoch #6918, accuracy_rate=0.677
# Epoch #6919, accuracy_rate=0.323
# Epoch #6920, accuracy_rate=0.677
# Epoch #6921, accuracy_rate=0.323
# Epoch #6922, accuracy_rate=0.677
# Epoch #6923, accuracy_rate=0.323
# Epoch #6924, accuracy_rate=0.677
# Epoch #6925, accuracy_rate=0.323
# Epoch #6926, accuracy_rate=0.677
# Epoch #6927, accuracy_rate=0.323
# Epoch #6928, accuracy_rate=0.677
# Epoch #6929, accuracy_rate=0.323
# Epoch #6930, accuracy_rate=0.677
# Epoch #6931, accuracy_rate=0.323
# Epoch #6932, accuracy_rate=0.677
# Epoch #6933, accuracy_rate=0.323
# Epoch #6934, accuracy_rate=0.677
# Epoch #6935, accuracy_rate=0.323
# Epoch #6936, accuracy_rate=0.677
# Epoch #6937, accuracy_rate=0.323
# Epoch #6938, accuracy_rate=0.677
# Epoch #6939, accuracy_rate=0.323
# Epoch #6940, accuracy_rate=0.677
# Epoch #6941, accuracy_rate=0.323
# Epoch #6942, accuracy_rate=0.677
# Epoch #6943, accuracy_rate=0.323
# Epoch #6944, accuracy_rate=0.677
# Epoch #6945, accuracy_rate=0.323
# Epoch #6946, accuracy_rate=0.677
# Epoch #6947, accuracy_rate=0.323
# Epoch #6948, accuracy_rate=0.677
# Epoch #6949, accuracy_rate=0.323
# Epoch #6950, accuracy_rate=0.677
# Epoch #6951, accuracy_rate=0.323
# Epoch #6952, accuracy_rate=0.677
# Epoch #6953, accuracy_rate=0.323
# Epoch #6954, accuracy_rate=0.677
# Epoch #6955, accuracy_rate=0.323
# Epoch #6956, accuracy_rate=0.677
# Epoch #6957, accuracy_rate=0.323
# Epoch #6958, accuracy_rate=0.677
# Epoch #6959, accuracy_rate=0.323
# Epoch #6960, accuracy_rate=0.677
# Epoch #6961, accuracy_rate=0.323
# Epoch #6962, accuracy_rate=0.677
# Epoch #6963, accuracy_rate=0.323
# Epoch #6964, accuracy_rate=0.677
# Epoch #6965, accuracy_rate=0.323
# Epoch #6966, accuracy_rate=0.677
# Epoch #6967, accuracy_rate=0.323
# Epoch #6968, accuracy_rate=0.677
# Epoch #6969, accuracy_rate=0.323
# Epoch #6970, accuracy_rate=0.677
# Epoch #6971, accuracy_rate=0.323
# Epoch #6972, accuracy_rate=0.677
# Epoch #6973, accuracy_rate=0.323
# Epoch #6974, accuracy_rate=0.677
# Epoch #6975, accuracy_rate=0.323
# Epoch #6976, accuracy_rate=0.677
# Epoch #6977, accuracy_rate=0.323
# Epoch #6978, accuracy_rate=0.677
# Epoch #6979, accuracy_rate=0.323
# Epoch #6980, accuracy_rate=0.677
# Epoch #6981, accuracy_rate=0.323
# Epoch #6982, accuracy_rate=0.677
# Epoch #6983, accuracy_rate=0.323
# Epoch #6984, accuracy_rate=0.677
# Epoch #6985, accuracy_rate=0.323
# Epoch #6986, accuracy_rate=0.677
# Epoch #6987, accuracy_rate=0.323
# Epoch #6988, accuracy_rate=0.677
# Epoch #6989, accuracy_rate=0.323
# Epoch #6990, accuracy_rate=0.677
# Epoch #6991, accuracy_rate=0.323
# Epoch #6992, accuracy_rate=0.677
# Epoch #6993, accuracy_rate=0.323
# Epoch #6994, accuracy_rate=0.677
# Epoch #6995, accuracy_rate=0.323
# Epoch #6996, accuracy_rate=0.677
# Epoch #6997, accuracy_rate=0.323
# Epoch #6998, accuracy_rate=0.677
# Epoch #6999, accuracy_rate=0.323
# After 6999 epoch(s), 5.817 s elapsed:
# Weight matrix = [-0.00158062 -0.00159346 -0.00167577  0.00021   ]
# Accuracy rate=0.68

# %%
print prediction.T, (prediction==train_y).sum()
# Out:
# [[-1. -1. -1. ... -1. -1. -1.]] 1355

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.scatter(range(len(misclassification)), misclassification, marker='*')
plt.xlabel('Epoch #')
plt.ylabel('Misclassifications')
plt.show()
